// %%
import kotlin.concurrent.thread

// Basic Thread creation
val thread = Thread {
    println("Running on thread -> ${Thread.currentThread().name}")
}
thread.start()

// Using Kotlin's thread {} builder
thread(name = "worker-1") {
    println("Worker thread running ->  ${Thread.currentThread().name}")
}
// Out:
// Running on thread -> Thread-79
// Worker thread running ->  worker-1
// Thread[#128,worker-1,5,]
