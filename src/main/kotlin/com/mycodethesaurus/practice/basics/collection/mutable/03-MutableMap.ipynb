// %%
val houseOfStarks = mutableMapOf<Int, String>()
houseOfStarks.put(0, "Ned Stark")
houseOfStarks.put(1, "Jon Snow")
houseOfStarks.put(2, "Arya Stark")
houseOfStarks.put(3, "Sansa Stark")
houseOfStarks[4]="Robb Stark"
//println(houseOfStarks)

houseOfStarks.forEach { k, v -> println("$k: $v") }
// Out:
// 0: Ned Stark
// 1: Jon Snow
// 2: Arya Stark
// 3: Sansa Stark
// 4: Robb Stark
